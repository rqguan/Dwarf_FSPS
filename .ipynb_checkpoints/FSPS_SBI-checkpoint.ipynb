# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Cell magic method always stays at the top of the cell

# Imports from the Python standard library should be at the top
import os
import copy
import pickle
import itertools 

# Do not import * unless you know what you are doing
import numpy as np 
import pandas as pd

import fsps
import sedpy
import lineid_plot

from sedpy.observate import getSED, vac2air, air2vac

import matplotlib.pyplot as plt
from matplotlib import rc
plt.rc('text', usetex=True)

import astropy.units as u
from astropy.io import ascii
from astropy.table import Table, Column
from astropy.constants import c, L_sun, pc
from astropy.cosmology import FlatLambdaCDM
from astropy.io import fits

from specutils import Spectrum1D
from specutils import SpectralRegion
from specutils.fitting import fit_generic_continuum
from specutils.analysis import equivalent_width

from prospect import models
from prospect.models import priors

from scipy.stats import entropy

import torch
import torch.nn as nn
import sbi.utils as utils
from sbi.inference.base import infer


# re-defining plotting defaults
from matplotlib import rcParams

from dwarf_models import SDSS_EMLINES, simulate_dwarf_sed, test_single_model,\
    sigma_clipping_continuum, measure_ew_emission_line, design_model_grid,\
    generate_dwarf_population, measure_color_ew, plot_models_with_sdss, setup_fsps_spop

rcParams.update({'xtick.major.pad': '7.0'})
rcParams.update({'xtick.major.size': '7.5'})
rcParams.update({'xtick.major.width': '1.5'})
rcParams.update({'xtick.minor.pad': '7.0'})
rcParams.update({'xtick.minor.size': '3.5'})
rcParams.update({'xtick.minor.width': '1.0'})
rcParams.update({'ytick.major.pad': '7.0'})
rcParams.update({'ytick.major.size': '7.5'})
rcParams.update({'ytick.major.width': '1.5'})
rcParams.update({'ytick.minor.pad': '7.0'})
rcParams.update({'ytick.minor.size': '3.5'})
rcParams.update({'ytick.minor.width': '1.0'})
rcParams.update({'axes.titlepad': '15.0'})
rcParams.update({'font.size': 22})

# %%
sdss_cat = Table.read('/Users/runquanguan/Documents/Dwarf_SDSS_8_9_SF_v2.0.fits')

em_flag = (np.isfinite(sdss_cat['M_u']) & np.isfinite(sdss_cat['M_r']) & \
           np.isfinite(sdss_cat['M_g']) & np.isfinite(sdss_cat['M_i']) &\
           np.isfinite(sdss_cat['OIII_5007_EQW']) & \
           np.isfinite(sdss_cat['H_ALPHA_EQW']) &\
           np.isfinite(sdss_cat['H_BETA_EQW']))

sdss_use = sdss_cat[em_flag]


SDSS_EMLINES = {\
    'OII_3726': {'cen':3726.032, 'low':3717.0, 'upp':3737.0},\
    'OII_3729': {'cen':3728.815, 'low':3717.0, 'upp':3737.0},\
    'NeIII_3869': {'cen':3869.060, 'low':3859.0, 'upp':3879.0}, \
    'H_delta': {'cen':4101.734, 'low':4092.0, 'upp':4111.0},\
    'H_gamma': {'cen':4340.464, 'low':4330.0, 'upp':4350.0},\
    'OIII_4363': {'cen':4363.210, 'low':4350.0, 'upp':4378.0},\
    'H_beta': {'cen':4861.325, 'low':4851.0, 'upp':4871.0},\
    'OIII_4959': {'cen':4958.911, 'low':4949.0, 'upp':4969.0},\
    'OIII_5007': {'cen':5006.843, 'low':4997.0, 'upp':5017.0},\
    'HeI_5876': {'cen':5875.67, 'low':5866.0, 'upp':5886.0},\
    'OI_6300': {'cen':6300.304, 'low':6290.0, 'upp':6310.0},\
    'NII_6548': {'cen':6548.040, 'low':6533.0, 'upp':6553.0},\
    'H_alpha': {'cen':6562.800, 'low':6553.0, 'upp':6573.0},\
    'NII_6584': {'cen':6583.460, 'low':6573.0, 'upp':6593.0},\
    'SII_6717': {'cen':6716.440, 'low':6704.0, 'upp':6724.0},\
    'SII_6731': {'cen':6730.810, 'low':6724.0, 'upp':6744.0},\
    'ArIII7135': {'cen':7135.8, 'low':7130.0, 'upp':7140.0}
}

# %%
prior = utils.BoxUniform(low=-2*torch.ones(num_dim), high=2*torch.ones(num_dim))

utils.BoxUniform?

# %%
from prospect.models import priors

# Gaussian distribution with boundary as prior for key parameters


tau_mean = priors.ClippedNormal(mean=2.6, sigma=0.3, mini=1.0, maxi=8.0)
const_mean = priors.ClippedNormal(mean=0.3, sigma=0.1, mini=0.0, maxi=0.49)
tage_mean = priors.ClippedNormal(mean=6.5, sigma=0.3, mini=1.0, maxi=11.0)
fburst_mean = priors.ClippedNormal(mean=0.6, sigma=0.1, mini=0.0, maxi=0.8)
tburst_mean = priors.ClippedNormal(mean=5.0, sigma=0.5, mini=0.0, maxi=8.0)
logzsol_mean = priors.ClippedNormal(mean=-0.8, sigma=0.5, mini=-1.5, maxi=0.0)
gas_logz_mean = priors.ClippedNormal(mean=-0.5, sigma=0.5, mini=-1.5, maxi=0.0)
gas_logu_mean = priors.ClippedNormal(mean=-3.2, sigma=0.5, mini=-4.0, maxi=-1.0)


prior = tau_mean, const_mean, tage_mean, fburst_mean, tburst_mean, logzsol_mean, gas_logz_mean, gas_logu_mean

# %%
def data_to_distribution(true_set, bins_range):
    
    sps_hist = np.histogram(true_set, bins = bins_range)[0]
    
    sps_hist_norm = [float(i+1e-4)/sum(sps_hist) for i in sps_hist]
    
    
    return sps_hist_norm

# %%
def sps_simulator(args):

    tau_mean, const_mean, tage_mean, fburst_mean, tburst_mean, logzsol_mean, gas_logz_mean, gas_logu_mean = args
    
    set_size = 5000

    tau_arr = [float(priors.ClippedNormal(mean=tau_mean, sigma=0.5, 
                                          mini=1.0, maxi=8.0).sample()) for _ in range(set_size)]
    const_arr =  [float(priors.ClippedNormal(mean=const_mean, sigma=0.3, 
                                             mini=0.0, maxi=0.5).sample()) for _ in range(set_size)]
    tage_arr =  [float(priors.ClippedNormal(mean=tage_mean, sigma=0.5, 
                                            mini=1.0, maxi=11.0).sample()) for _ in range(set_size)]
    fburst_arr =  [float(priors.ClippedNormal(mean=fburst_mean, sigma=0.3, 
                                              mini=0.0, maxi=0.8).sample()) for _ in range(set_size)]
    tburst_arr =  [float(priors.ClippedNormal(mean=tburst_mean, sigma=0.7, 
                                              mini=0.0, maxi=8.0).sample()) for _ in range(set_size)]
    logzsol_arr =  [float(priors.ClippedNormal(mean=logzsol_mean, sigma=0.5, 
                                               mini=-1.5, maxi=0.0).sample()) for _ in range(set_size)]
    gas_logz_arr =  [float(priors.ClippedNormal(mean=gas_logz_mean, sigma=0.7, 
                                                mini=-1.5, maxi=0.0).sample()) for _ in range(set_size)]
    gas_logu_arr =  [float(priors.ClippedNormal(mean=gas_logu_mean, sigma=0.7, 
                                                mini=-4.0, maxi=-1.0).sample()) for _ in range(set_size)]

    # Fix the fburst + const > 1 issue
    for ii in np.arange(len(const_arr)):
        if const_arr[ii] + fburst_arr[ii] >= 0.95:
            f_over = (const_arr[ii] + fburst_arr[ii]) - 0.95
            if fburst_arr[ii] >= (f_over + 0.01):
                fburst_arr[ii] = fburst_arr[ii] - (f_over + 0.01)
            else:
                const_arr[ii] = const_arr[ii] - (f_over + 0.01)

    # Fixed the rest
    dust1_arr = np.full(set_size, 0.1)
    dust2_arr = np.full(set_size, 0.0)
    sf_trunc_arr = np.full(set_size, 0.0)

    # List of model parameters
    dwarf_sample_parameters = [
         {
             'dust1': dust1_arr[ii], 
             'dust2': dust2_arr[ii],
             'logzsol': logzsol_arr[ii], 
             'gas_logz': gas_logz_arr[ii], 
             'gas_logu': gas_logu_arr[ii],
             'const': const_arr[ii], 
             'tau': tau_arr[ii], 
             'tage': tage_arr[ii],
             'sf_trunc': sf_trunc_arr[ii], 
             'fburst': fburst_arr[ii], 
             'tburst': tburst_arr[ii]
         } for ii in np.arange(set_size)
    ]

    # Double check
    for ii, model in enumerate(dwarf_sample_parameters):
        if model['fburst'] + model['const'] >= 0.99:
            print(ii, model['fburst'], model['const'])
            
            
    # Initialize the spop model
    spop_tau = setup_fsps_spop(
        zcontinuous=1, imf_type=2, sfh=1, dust_type=0, 
        dust_index=-1.3, dust1_index=-1.0)


    # Measure colors and emission line EWs
    # - SDSS_EMLINES is a pre-defined dict of emission lines center wavelength and the 
    # wavelength window for measuring EW.
    # - You can save the results in a numpy array
    dwarf_sample_table = measure_color_ew(
        dwarf_sample_gaussian, em_list=SDSS_EMLINES, output=None)
    
    bin_size = 200
    
    sps_ur = data_to_distribution(dwarf_sample_table['ur_color'], np.linspace(0,2.5,bin_size))
    sps_ug = data_to_distribution(dwarf_sample_table['ug_color'], np.linspace(0,1.75,bin_size))
    sps_gr = data_to_distribution(dwarf_sample_table['gr_color'], np.linspace(-0.1,0.8,bin_size))
    sps_gi = data_to_distribution(dwarf_sample_table['gi_color'], np.linspace(-0.2,1.2,bin_size))
    sps_ha = data_to_distribution(np.log10(dwarf_sample_table['ew_halpha']), np.linspace(0,3,bin_size))
    sps_hb = data_to_distribution(np.log10(dwarf_sample_table['ew_hbeta']), np.linspace(-0.5,2.5,bin_size))
    sps_oiii = data_to_distribution(np.log10(dwarf_sample_table['ew_oiii_5007']), np.linspace(-1,3,bin_size))
    
    
    simulate_post = np.transpose(np.vstack([sps_ur, sps_ug, 
                                   sps_gr, sdss_gi, 
                                   sps_ha, sps_hb, 
                                   sps_oiii]))

   

    return simulate_post

# %%
sdss_data = sdss_use
bin_size = 200

sdss_ur = data_to_distribution(np.asarray(sdss_use['M_u'] - sdss_use['M_r']), np.linspace(0,2.5,bin_size))
sdss_ug = data_to_distribution(np.asarray(sdss_use['M_u'] - sdss_use['M_g']), np.linspace(0,1.75,bin_size))
sdss_gr = data_to_distribution(np.asarray(sdss_use['M_g'] - sdss_use['M_r']), np.linspace(-0.1,0.8,bin_size))
sdss_gi = data_to_distribution(np.asarray(sdss_use['M_g'] - sdss_use['M_i']), np.linspace(-0.2,1.2,bin_size))
sdss_ha = data_to_distribution(np.log10(-1.0*sdss_use['H_ALPHA_EQW']), np.linspace(0,3,bin_size))
sdss_hb = data_to_distribution(np.log10(-1.0*sdss_use['H_BETA_EQW']), np.linspace(-0.5,2.5,bin_size))
sdss_oiii = data_to_distribution(np.log10(-1.0 * (sdss_use['OIII_5007_EQW'])), np.linspace(-1,3,bin_size))



observation = np.transpose(np.vstack([sdss_ur, sdss_ug, 
                                       sdss_gr, sdss_gi, 
                                       sdss_ha, sdss_hb, 
                                       sdss_oiii]))
# Out:
# /Users/runquanguan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log10
#
# /Users/runquanguan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in log10
#
# /Users/runquanguan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# /Users/runquanguan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in log10
#   if __name__ == '__main__':
# /Users/runquanguan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log10
#   # Remove the CWD from sys.path while we load stuff.
# /Users/runquanguan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in log10
#   # Remove the CWD from sys.path while we load stuff.

# %%
posterior = infer(sps_simulator, prior, method='SNPE', num_simulations=1000)
# Out:
# /Users/runquanguan/anaconda3/lib/python3.7/site-packages/sbi/user_input/user_input_checks.py:45: UserWarning: Prior was provided as a sequence of 8 priors. They will be
#             interpreted as independent of each other and matched in order to the
#             components of the parameter.
#   components of the parameter."""
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-33-82fe5fa38f92> in <module>
# ----> 1 posterior = infer(sps_simulator, prior, method='SNPE', num_simulations=1000)
#
# ~/anaconda3/lib/python3.7/site-packages/sbi/inference/base.py in infer(simulator, prior, method, num_simulations, num_workers)
#      64         )
#      65
# ---> 66     simulator, prior = prepare_for_sbi(simulator, prior)
#      67
#      68     infer_ = method_fun(simulator, prior, num_workers=num_workers)
#
# ~/anaconda3/lib/python3.7/site-packages/sbi/user_input/user_input_checks.py in prepare_for_sbi(simulator, prior)
#     477
#     478     # Check prior, return PyTorch prior.
# --> 479     prior, _, prior_returns_numpy = process_prior(prior)
#     480
#     481     # Check simulator, returns PyTorch simulator able to simulate batches.
#
# ~/anaconda3/lib/python3.7/site-packages/sbi/user_input/user_input_checks.py in process_prior(prior)
#      45             components of the parameter."""
#      46         )
# ---> 47         return process_pytorch_prior(MultipleIndependent(prior))
#      48
#      49     if isinstance(prior, Distribution):
#
# ~/anaconda3/lib/python3.7/site-packages/sbi/user_input/user_input_checks_utils.py in __init__(self, dists, validate_args)
#     173         self, dists: Sequence[Distribution], validate_args=None,
#     174     ) -> MultipleIndependent:
# --> 175         self._check_distributions(dists)
#     176
#     177         self.dists = dists
#
# ~/anaconda3/lib/python3.7/site-packages/sbi/user_input/user_input_checks_utils.py in _check_distributions(self, dists)
#     197         assert len(dists) > 1, "Provide at least 2 distributions to combine."
#     198         # Check every element of the sequence.
# --> 199         [self._check_distribution(d) for d in dists]
#     200
#     201     def _check_distribution(self, dist: Distribution):
#
# ~/anaconda3/lib/python3.7/site-packages/sbi/user_input/user_input_checks_utils.py in <listcomp>(.0)
#     197         assert len(dists) > 1, "Provide at least 2 distributions to combine."
#     198         # Check every element of the sequence.
# --> 199         [self._check_distribution(d) for d in dists]
#     200
#     201     def _check_distribution(self, dist: Distribution):
#
# ~/anaconda3/lib/python3.7/site-packages/sbi/user_input/user_input_checks_utils.py in _check_distribution(self, dist)
#     207         assert isinstance(
#     208             dist, Distribution
# --> 209         ), "Distribution must be a PyTorch distribution."
#     210         # Make sure batch shape is smaller or equal to 1.
#     211         assert dist.batch_shape in (
#
# AssertionError: Distribution must be a PyTorch distribution.
